# %%
import easyocr
import pytesseract
from PIL import Image, ImageDraw, ImageGrab
from pdf2image import convert_from_path as cfp
import cv2
from matplotlib import pyplot as plt
import numpy as np
from IPython.display import display
import time

# %%
img_path = '/home/kanishk/projects/ocr/samples/sample1.jpg'

im = Image.open(img_path)
display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1700x2200>

# %%
pytesseract.pytesseract.tesseract_cmd = '/usr/bin/tesseract'
img = cv2.imread('/home/kanishk/projects/ocr/samples/sample2.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
boxes = pytesseract.image_to_boxes(img)
boxes = pytesseract.image_to_data(img)
for a,b in enumerate(boxes.splitlines()):
        print(b)
        if a!=0:
            b = b.split()
            if len(b)==12:
                x,y,w,h = int(b[6]),int(b[7]),int(b[8]),int(b[9])
                cv2.putText(img,b[11],(x,y-5),cv2.FONT_HERSHEY_SIMPLEX,1,(50,50,255),2)
                cv2.rectangle(img, (x,y), (x+w, y+h), (50, 50, 255), 2)
# Out:
# level	page_num	block_num	par_num	line_num	word_num	left	top	width	height	conf	text
# 1	1	0	0	0	0	0	0	464	619	-1
# 2	1	1	0	0	0	0	4	464	615	-1
# 3	1	1	1	0	0	0	4	464	615	-1
# 4	1	1	1	1	0	0	4	464	615	-1
# 5	1	1	1	1	1	0	4	464	615	95

# %%
cv2.imshow('img', img)
cv2.waitKey(0)
