# %%
import easyocr
import pytesseract
from PIL import Image, ImageDraw
import PyPDF2
from pdf2image import convert_from_path as cfp
import cv2
from matplotlib import pyplot as plt
import numpy as np
from IPython.display import display

# %%
imgpath = '/home/kanishk/projects/ocr/notation-test.pdf'
imgs = cfp('notation-test.pdf')

for i in range(len(imgs)):
    imgs[i].save('note-sheet' + str(i) + '.jpg', 'JPEG')
sheet = imgs[0]
display(sheet)
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200>

# %%
pytesseract.image_to_string(sheet)

# %%
reader = easyocr.Reader(['en'], gpu=True)
text = reader.readtext(np.array(sheet))
text

# %%
bounds = reader.readtext(np.array(imgs[0]))
bounds

# %%
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'
img = cv2.imread('1.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
